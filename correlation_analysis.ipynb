# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/공공데이터 공모전/DATASET')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
hatecrime=pd.read_csv("hatecrime.csv")
overdose=pd.read_csv("overdosedeath.csv")
unemployment=pd.read_csv("unemployment.csv")
ethnicity=pd.read_csv('ethnicity.csv')
race=pd.read_csv('race.csv')
age=pd.read_csv('age.csv')
gender=pd.read_csv('gender.csv')
overdose911=pd.read_csv('overdose911.csv')
homePrice=pd.read_csv('homePriceIndex.csv')
GDP=pd.read_csv('GDP.csv')

# %% [markdown]
# # 전처리

# %%
#전처리
#ethnicity
cali_ethnicity=pd.DataFrame()
cali_ethnicity= ethnicity[ethnicity['LOCATION_ID'] == 'CA-501'].copy()
cali_ethnicity.reset_index(drop=True, inplace=True)

#race
cali_race=pd.DataFrame()
cali_race= race[race['LOCATION_ID'] == 'CA-501'].copy()
cali_race.reset_index(drop=True, inplace=True)

#age
cali_age=pd.DataFrame()
cali_age= age[age['LOCATION_ID'] == 'CA-501'].copy()
cali_age.reset_index(drop=True, inplace=True)

#gender
cali_gender=pd.DataFrame()
cali_gender= gender[gender['LOCATION_ID'] == 'CA-501'].copy()
cali_gender.reset_index(drop=True, inplace=True)

# %%
#unemployment 년도별로 정리
sum_2017=0
sum_2018=0
sum_2019=0
sum_2020=0
sum_2021=0
sum_2022=0

sum_2023=0
for index, row in unemployment.iterrows():
    if row['DATE'][:4] == '2017':
        sum_2017 += row['CASANF0URN']
for index, row in unemployment.iterrows():
    if row['DATE'][:4] == '2018':
        sum_2018 += row['CASANF0URN']
for index, row in unemployment.iterrows():
    if row['DATE'][:4] == '2019':
        sum_2019 += row['CASANF0URN']
for index, row in unemployment.iterrows():
    if row['DATE'][:4] == '2020':
        sum_2020 += row['CASANF0URN']
for index, row in unemployment.iterrows():
    if row['DATE'][:4] == '2021':
        sum_2021 += row['CASANF0URN']
for index, row in unemployment.iterrows():
    if row['DATE'][:4] == '2022':
        sum_2022 += row['CASANF0URN']




df_unemployment=pd.DataFrame({'DATE': ['2017', '2018', '2019', '2020','2021','2022'],
                     'unemployment': [2.5,2.2,2.0,6.6,3.1,2.2]})

print(df_unemployment)
# Out:
#    DATE  unemployment
# 0  2017           2.5
# 1  2018           2.2
# 2  2019           2.0
# 3  2020           6.6
# 4  2021           3.1
# 5  2022           2.2

# %%
#overdose 정리
sum_2020=0
sum_2021=0
sum_2022=0
sum_2023=0

for index, row in overdose.iterrows():
    if str(row['year'])[:4] == '2020':
        sum_2020 += row['total_deaths']
for index, row in overdose.iterrows():
    if str(row['year'])[:4] == '2021':
        sum_2021 += row['total_deaths']
for index, row in overdose.iterrows():
    if str(row['year'])[:4] == '2022':
        sum_2022 += row['total_deaths']
for index, row in overdose.iterrows():
    if str(row['year'])[:4] == '2023':
        sum_2023 += row['total_deaths']

df_overdose=pd.DataFrame({'DATE': ['2017','2018','2019','2020','2021','2022'],
                     'overdose': [222,259,441,sum_2020,sum_2021,sum_2022]})

print(df_overdose)
# Out:
#    DATE  overdose
# 0  2017       222
# 1  2018       259
# 2  2019       441
# 3  2020       725
# 4  2021       641
# 5  2022       647

# %%
#overdose911 정의
sum_2022=0
sum_2023=0

for index, row in overdose911.iterrows():
    if str(row['year']) == '2022':
        sum_2022 += row['total_overdose_related_911_calls']
for index, row in overdose911.iterrows():
    if str(row['year']) == '2023':
        sum_2023 += row['total_overdose_related_911_calls']

df_overdose911=pd.DataFrame({'DATE': ['2022','2023'],
                     'overdose911': [sum_2022,sum_2023]})

print(df_overdose911)
# Out:
#    DATE  overdose911
# 0  2022         1313
# 1  2023         2837

# %%
#homePrice 정리

sum_2017=0
sum_2018=0
sum_2019=0
sum_2020=0
sum_2021=0
sum_2022=0
sum_2023=0

for index, row in homePrice.iterrows():
    if row['DATE'][:4] == '2017':
        sum_2017 += row['homeprice']
for index, row in homePrice.iterrows():
    if row['DATE'][:4] == '2018':
        sum_2018 += row['homeprice']
for index, row in homePrice.iterrows():
    if row['DATE'][:4] == '2019':
        sum_2019 += row['homeprice']
for index, row in homePrice.iterrows():
    if row['DATE'][:4] == '2020':
        sum_2020 += row['homeprice']
for index, row in homePrice.iterrows():
    if row['DATE'][:4] == '2021':
        sum_2021 += row['homeprice']
for index, row in homePrice.iterrows():
    if row['DATE'][:4] == '2022':
        sum_2022 += row['homeprice']
for index, row in homePrice.iterrows():
    if row['DATE'][:4] == '2023':
        sum_2023 += row['homeprice']

df_homeprice=pd.DataFrame({'DATE': ['2017','2018','2019','2020','2021','2022'],
                     'homeprice': [255.81,265.05,271.36,296.61,353.11,338.46]})

print(df_homeprice)
# Out:
#    DATE  homeprice
# 0  2017     255.81
# 1  2018     265.05
# 2  2019     271.36
# 3  2020     296.61
# 4  2021     353.11
# 5  2022     338.46

# %%
#interestRate 입력
df_interestRate=pd.DataFrame({'DATE': ['2017','2018','2019','2020','2021','2022','2023'],
                     'interestRate': [0.04,0.04,0.06,0.05,0.03,0.03,0.05]})
df_interestRate
# Out:
#    DATE  interestRate
# 0  2017          0.04
# 1  2018          0.04
# 2  2019          0.06
# 3  2020          0.05
# 4  2021          0.03
# 5  2022          0.03
# 6  2023          0.05

# %%
#GDP 정리

sum_2017=0
sum_2018=0
sum_2019=0
sum_2020=0
sum_2021=0
sum_2022=0
sum_2023=0

for index, row in GDP.iterrows():
    if row['DATE'][:4] == '2017':
        sum_2017 += row['GDP']
for index, row in GDP.iterrows():
    if row['DATE'][:4] == '2018':
        sum_2018 += row['GDP']
for index, row in GDP.iterrows():
    if row['DATE'][:4] == '2019':
        sum_2019 += row['GDP']
for index, row in GDP.iterrows():
    if row['DATE'][:4] == '2020':
        sum_2020 += row['GDP']
for index, row in GDP.iterrows():
    if row['DATE'][:4] == '2021':
        sum_2021 += row['GDP']
for index, row in GDP.iterrows():
    if row['DATE'][:4] == '2022':
        sum_2022 += row['GDP']

df_GDP=pd.DataFrame({'DATE': ['2017','2018','2019','2020','2021','2022'],
                     'GDP': [19894.75,20819.269,21706.532,21704.706,24349.121,26137.992]})

print(df_GDP)
# Out:
#    DATE        GDP
# 0  2017  19894.750
# 1  2018  20819.269
# 2  2019  21706.532
# 3  2020  21704.706
# 4  2021  24349.121
# 5  2022  26137.992

# %%
#hateCrimes
df_hatecrimes=pd.DataFrame({'DATE': ['2017','2018','2020'],
                     'hatecrime': [29,53,40]})

print(df_hatecrimes)
# Out:
#    DATE  hatecrime
# 0  2017         29
# 1  2018         53
# 2  2020         40

# %%
#population
df_population=pd.DataFrame({'DATE': ['2017','2018','2019','2020','2021','2022'],
                     'population': [879166,883305,881549,873965,815200,821405]})

print(df_population)
# Out:
#    DATE  population
# 0  2017      879166
# 1  2018      883305
# 2  2019      881549
# 3  2020      873965
# 4  2021      815200
# 5  2022      821405

# %%
cali_gender.head(20)
cali_gender['CALENDAR_YEAR'] = cali_gender['CALENDAR_YEAR'].astype(str)
idx=cali_gender[cali_gender['EXPERIENCING_HOMELESSNESS']=="*"].index
cali_gender.drop(idx,inplace=True)

# %%
#cali_gender 정리
sum_2017=0
sum_2018=0
sum_2019=0
sum_2020=0
sum_2021=0
sum_2022=0
sum_2023=0

for index, row in cali_gender.iterrows():
    if str(row['CALENDAR_YEAR'])[:4] == '2017':
        sum_2017 += int(row['EXPERIENCING_HOMELESSNESS'])
for index, row in cali_gender.iterrows():
    if str(row['CALENDAR_YEAR'])[:4] == '2018':
        sum_2018 += int(row['EXPERIENCING_HOMELESSNESS'])
for index, row in cali_gender.iterrows():
    if str(row['CALENDAR_YEAR'])[:4] == '2019':
        sum_2019 += int(row['EXPERIENCING_HOMELESSNESS'])
for index, row in cali_gender.iterrows():
    if str(row['CALENDAR_YEAR'])[:4] == '2020':
        sum_2020 += int(row['EXPERIENCING_HOMELESSNESS'])
for index, row in cali_gender.iterrows():
    if str(row['CALENDAR_YEAR'])[:4] == '2021':
        sum_2021 += int(row['EXPERIENCING_HOMELESSNESS'])
for index, row in cali_gender.iterrows():
    if str(row['CALENDAR_YEAR'])[:4] == '2022':
        sum_2022 += int(row['EXPERIENCING_HOMELESSNESS'])
for index, row in cali_gender.iterrows():
    if str(row['CALENDAR_YEAR'])[:4] == '2023':
        sum_2023 += int(row['EXPERIENCING_HOMELESSNESS'])

df_homeless=pd.DataFrame({'DATE': ['2017', '2018', '2019', '2020','2021','2022','2023'],
                     'homeless': [sum_2017,sum_2018,sum_2019,sum_2020,sum_2021,sum_2022,sum_2023]})

print(df_homeless)
# Out:
#    DATE  homeless
# 0  2017      4368
# 1  2018      5656
# 2  2019      8016
# 3  2020     11554
# 4  2021     13904
# 5  2022     18224
# 6  2023     10346

# %% [markdown]
# # 노숙자 회귀분석

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
homeless_array=df_homeless.homeless[0:6].to_numpy()
Y=homeless_array.reshape(-1,1)
DATE_array=df_homeless.DATE[0:6].to_numpy()
X=DATE_array.reshape(-1,1)

# %%
lr.fit(X,Y)
# Out:
# LinearRegression()

# %%
print(lr.coef_[0])
print(lr.intercept_)
# Out:
# [2787.48571429]
# [-5619040.4]

# %%
import matplotlib.pyplot as plt
X=X.flatten()
Y=Y.flatten()
plt.scatter(X,Y)
plt.plot(X,Y,color='pink')
plt.title('y={}*x+{}'.format(lr.coef_[0],lr.intercept_))
plt.show()

# %%
df_homeless
# Out:
#    DATE  homeless
# 0  2017      4368
# 1  2018      5656
# 2  2019      8016
# 3  2020     11554
# 4  2021     13904
# 5  2022     18224
# 6  2023     10346

# %%
estimated_2023=lr.coef_[0]*2023+lr.intercept_
df_homeless.iloc[6,1]=estimated_2023
df_homeless
# Out:
#    DATE  homeless
# 0  2017    4368.0
# 1  2018    5656.0
# 2  2019    8016.0
# 3  2020   11554.0
# 4  2021   13904.0
# 5  2022   18224.0
# 6  2023   20043.2

# %% [markdown]
# # 회귀분석 검증

# %%
import statsmodels.api as sm
import numpy as np

X = pd.to_numeric(X)
Y = pd.to_numeric(Y)

# %%
Y = pd.to_numeric(Y, errors='coerce')
X = pd.to_numeric(X, errors='coerce')

# %%
import numpy as np
Y = np.array(Y)
X = np.array(X)

# 선형 회귀 모델 적합
X = sm.add_constant(X)  # 상수 항을 추가 (intercept)
results = sm.OLS(Y, X).fit()

# 결과 출력
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     162.6
# Date:                Sat, 30 Sep 2023   Prob (F-statistic):           0.000218
# Time:                        17:34:30   Log-Likelihood:                -48.208
# No. Observations:                   6   AIC:                             100.4
# Df Residuals:                       4   BIC:                             100.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.619e+06   4.42e+05    -12.727      0.000   -6.84e+06   -4.39e+06
# ...

# %% [markdown]
# # 상관관계분석

# %%
data = pd.merge(df_unemployment, df_overdose,on='DATE',how='left')
data
# Out:
#    DATE  unemployment  overdose
# 0  2017           2.5       222
# 1  2018           2.2       259
# 2  2019           2.0       441
# 3  2020           6.6       725
# 4  2021           3.1       641
# 5  2022           2.2       647

# %%
data=pd.merge(data,df_homeprice,on='DATE',how='left')
data
# Out:
#    DATE  unemployment  overdose  homeprice
# 0  2017           2.5       222     255.81
# 1  2018           2.2       259     265.05
# 2  2019           2.0       441     271.36
# 3  2020           6.6       725     296.61
# 4  2021           3.1       641     353.11
# 5  2022           2.2       647     338.46

# %%
data=pd.merge(data,df_interestRate,on='DATE',how='left')
data
# Out:
#    DATE  unemployment  overdose  homeprice  interestRate
# 0  2017           2.5       222     255.81          0.04
# 1  2018           2.2       259     265.05          0.04
# 2  2019           2.0       441     271.36          0.06
# 3  2020           6.6       725     296.61          0.05
# 4  2021           3.1       641     353.11          0.03
# 5  2022           2.2       647     338.46          0.03

# %%
data=pd.merge(data,df_GDP,on='DATE',how='left')
data
# Out:
#    DATE  unemployment  overdose  homeprice  interestRate        GDP
# 0  2017           2.5       222     255.81          0.04  19894.750
# 1  2018           2.2       259     265.05          0.04  20819.269
# 2  2019           2.0       441     271.36          0.06  21706.532
# 3  2020           6.6       725     296.61          0.05  21704.706
# 4  2021           3.1       641     353.11          0.03  24349.121
# 5  2022           2.2       647     338.46          0.03  26137.992

# %%
data=pd.merge(data,df_population,on='DATE',how='left')
data
# Out:
#    DATE  unemployment  overdose  homeprice  interestRate        GDP  \
# 0  2017           2.5       222     255.81          0.04  19894.750
# 1  2018           2.2       259     265.05          0.04  20819.269
# 2  2019           2.0       441     271.36          0.06  21706.532
# 3  2020           6.6       725     296.61          0.05  21704.706
# 4  2021           3.1       641     353.11          0.03  24349.121
# 5  2022           2.2       647     338.46          0.03  26137.992
#
#    population
# 0      879166
# 1      883305
# 2      881549
# 3      873965
# 4      815200
# 5      821405

# %%
#결측값 채우기
data=data.fillna(data.mean())
data
# Out:
#    DATE  unemployment  overdose  homeprice  interestRate        GDP  \
# 0  2017           2.5       222     255.81          0.04  19894.750
# 1  2018           2.2       259     265.05          0.04  20819.269
# 2  2019           2.0       441     271.36          0.06  21706.532
# 3  2020           6.6       725     296.61          0.05  21704.706
# 4  2021           3.1       641     353.11          0.03  24349.121
# 5  2022           2.2       647     338.46          0.03  26137.992
#
#    population
# 0      879166
# 1      883305
# 2      881549
# 3      873965
# 4      815200
# 5      821405

# %%
data = pd.merge(data,df_homeless,on='DATE',how='inner')
data
# Out:
#    DATE  unemployment  overdose  homeprice  interestRate        GDP  homeless
# 0  2017           2.5       222     255.81          0.04  19894.750    4368.0
# 1  2018           2.2       259     265.05          0.04  20819.269    5656.0
# 2  2019           2.0       441     271.36          0.06  21706.532    8016.0
# 3  2020           6.6       725     296.61          0.05  21704.706   11554.0
# 4  2021           3.1       641     353.11          0.03  24349.121   13904.0
# 5  2022           2.2       647     338.46          0.03  26137.992   18224.0

# %%
correlation_matrix = data.corr()
print(correlation_matrix)
# Out:
#               unemployment  overdose  homeprice  interestRate       GDP  \
# unemployment      1.000000  0.585410   0.120524      0.214182 -0.102348
# overdose          0.585410  1.000000   0.793439     -0.135660  0.710705
# homeprice         0.120524  0.793439   1.000000     -0.627741  0.916066
# interestRate      0.214182 -0.135660  -0.627741      1.000000 -0.569309
# GDP              -0.102348  0.710705   0.916066     -0.569309  1.000000
# homeless          0.161892  0.857597   0.915959     -0.480602  0.962189
#
#               homeless
# unemployment  0.161892
# overdose      0.857597
# homeprice     0.915959
# interestRate -0.480602
# GDP           0.962189
# homeless      1.000000
# <ipython-input-41-e02734b85495>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))  # 그래프 크기 설정
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")  # annot=True는 숫자 표시, cmap은 색상 맵 설정

# 그래프 제목 설정
plt.title('Correlation Heatmap')

# 그래프 표시
plt.show()

# %% [markdown]
# # 상관분석 검증

# %%
p_value_matrix = pd.DataFrame(index=correlation_matrix.index, columns=correlation_matrix.columns)

for column1 in correlation_matrix.columns:
    for column2 in correlation_matrix.columns:
        if column1 != column2:
            corr_coeff, p_value = pearsonr(data[column1], data[column2])
            p_value_matrix.at[column1, column2] = p_value

# p-value 출력
print("\nP-value Matrix:")
print(p_value_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-128b4e2b67e4> in <cell line: 3>()
#       4     for column2 in correlation_matrix.columns:
#       5         if column1 != column2:
# ----> 6             corr_coeff, p_value = pearsonr(data[column1], data[column2])
#       7             p_value_matrix.at[column1, column2] = p_value
#       8
#
# NameError: name 'pearsonr' is not defined

# %% [markdown]
# 데이터 개수 자체가 적어서 유의미한 상관분석이 되진 못했음

# %% [markdown]
# # 마약 노숙자 시각화

# %%
df_overdose
# Out:
#      DATE  overdose  DATE_증가율  overdose_증가율  DATE_증가율_증가율  overdose_증가율_증가율  \
# 0  2017.0     222.0  0.000000      0.000000      0.000000          0.000000
# 1  2018.0     259.0  0.049579     16.666667      0.000000          0.000000
# 2  2019.0     441.0  0.049554     70.270270     -0.049554        321.621622
# 3  2020.0     725.0  0.049529     64.399093     -0.049529         -8.355137
# 4  2021.0     641.0  0.049505    -11.586207     -0.049505       -117.991258
# 5  2022.0     647.0  0.049480      0.936037     -0.049480       -108.078895
#
#    DATE_증가율_증가율_증가율  overdose_증가율_증가율_증가율  DATE_증가율_증가율_증가율_증가율  \
# 0          0.000000              0.000000              0.000000
# 1          0.000000              0.000000              0.000000
# 2          0.000000              0.000000              0.000000
# 3         -0.049529           -102.597816              0.000000
# 4         -0.049505           1312.200170             -0.049545
# ...

# %%
df_homeless
# Out:
#    DATE  homeless
# 0  2017    4368.0
# 1  2018    5656.0
# 2  2019    8016.0
# 3  2020   11554.0
# 4  2021   13904.0
# 5  2022   18224.0
# 6  2023   20043.2

# %%
df_homeless['DATE'] = df_homeless['DATE'].astype(float)
df_homeless['homeless'] = df_homeless['homeless'].astype(float)

# 증가율 계산 및 새로운 열 추가
for col in df_homeless.columns:
    df_homeless[col + '_증가율'] = df_homeless[col].pct_change() * 100  # 증가율을 백분율로 표시

# NaN 값을 0으로 대체 (첫 번째 행의 증가율은 NaN이므로)
df_homeless = df_homeless.fillna(0)

# 결과 데이터프레임 출력

df_line2=df_homeless[['DATE','homeless_증가율']]
df_line2
# Out:
#      DATE  homeless_증가율
# 0  2017.0      0.000000
# 1  2018.0     29.487179
# 2  2019.0     41.725601
# 3  2020.0     44.136727
# 4  2021.0     20.339276
# 5  2022.0     31.070196
# 6  2023.0      9.982441

# %%
df_overdose['DATE'] = df_overdose['DATE'].astype(float)
df_overdose['overdose'] = df_overdose['overdose'].astype(float)

# 증가율 계산 및 새로운 열 추가
for col in df_overdose.columns:
    df_overdose[col + '_증가율'] = df_overdose[col].pct_change() * 100  # 증가율을 백분율로 표시

# NaN 값을 0으로 대체 (첫 번째 행의 증가율은 NaN이므로)
df_overdose = df_overdose.fillna(0)

# 결과 데이터프레임 출력

df_line1=df_overdose[['DATE','overdose_증가율']]
df_line1
# Out:
#      DATE  overdose_증가율
# 0  2017.0      0.000000
# 1  2018.0     16.666667
# 2  2019.0     70.270270
# 3  2020.0     64.399093
# 4  2021.0    -11.586207
# 5  2022.0      0.936037

# %%
df_homeless['DATE'] = df_homeless['DATE'].astype(str)
df_overdose['DATE'] = df_overdose['DATE'].astype(str)


plt.plot(df_line1['DATE'],df_line1['overdose_증가율'],label='overdose',marker='o',linestyle='-',color='blue')
plt.plot(df_line2['DATE'],df_line2['homeless_증가율'],label='homeless',marker='o',linestyle='-',color='red')
